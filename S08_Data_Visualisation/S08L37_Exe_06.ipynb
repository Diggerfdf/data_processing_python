# %%
import numpy
import pandas
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pandas.read_csv('./Exercise/US States Median Income Data.csv')
df = df.set_index(['GEOID', 'State'])
fig, axes = plt.subplots()
axes.tick_params(labelsize = 8)
sns.heatmap(df, ax = axes)
fig.savefig('./Exercise/Income_heatmap.png', dpi = 200)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-4cabadc606c9> in <module>
# ----> 1 test = sns.heatmap(df)
#
# ~/anaconda3/envs/Data_Analysis/lib/python3.7/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# ~/anaconda3/envs/Data_Analysis/lib/python3.7/site-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
# ...
